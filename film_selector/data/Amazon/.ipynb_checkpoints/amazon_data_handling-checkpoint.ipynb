# %% [markdown]
# # Data set handling and familiarisation
# I am using this jupyter notebook to examine and edit the Amazon data set aquired from Kaggle so that they only contain relevant columns, etc<br>I do the following for each data set:
# - Remove unecessary columns
# - Check for and handle any missing values
# - Map values in key columns to best suit the needs of the user
# - Create new data sets from the master set for each form of media i.e: a data set containing only fims, one containing TV shows, etc.

# %%
#Importing the relevant libraries
import pandas as pd

# %%
#read in data set and view headers
am = pd.read_csv("amazon_prime_titles.csv")
list(am.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
am2 = am.drop(columns=['show_id','cast','country'])

# %%
#check for missing values, I will use this to help me decide what columns to drop
am2.isnull().sum()
# Out:
# type               0
# title              0
# director        2082
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# As shown above, 'director', 'date_added' and 'rating' all have vast quantities of missing values thus I am going to drop all of these columns. So that both data sets match and thus the same logic can be applied to both I will also remove these columns in the netflix data set.

# %%
am2 = am2.drop(columns=['director','date_added','rating'])

# %%
# I want to obtain the varying 'listed in' values and map these to clearer genres - this better suites the needs of my target user.
am2['listed_in'].unique()
# Out:
# array(['Comedy, Drama', 'Drama, International', 'Action, Drama, Suspense',
#        'Documentary', 'Drama, Fantasy', 'Fantasy, Kids',
#        'Documentary, Special Interest', 'Comedy',
#        'Action, Science Fiction, Suspense', 'Drama', 'Adventure, Kids',
#        'Horror, Suspense', 'Documentary, Sports',
#        'Horror, Science Fiction', 'Kids, Special Interest',
#        'Comedy, Talk Show and Variety', 'Science Fiction', 'Kids',
#        'Action, Anime, Comedy',
#        'Arts, Entertainment, and Culture, Comedy, Drama', 'TV Shows',
#        'Animation, Anime, Fantasy', 'Action, Adventure, Animation',
#        'Anime, Kids', 'Music Videos and Concerts', 'Drama, Suspense',
#        'Fitness, Special Interest',
#        'Faith and Spirituality, Special Interest', 'Special Interest',
#        'Fitness', 'Action, Military and War, Western',
#        'Arts, Entertainment, and Culture, Comedy, Talk Show and Variety',
#        'Action, Western', 'Documentary, Science Fiction',
# ...

# %% [markdown]
# Below I map the varied 'listed_in' values to clear genres to better suit the purpose of the program

# %%
am2 = am2.replace({'Comedy, Drama':'Comedy', 'Drama, International':'Drama', 'Action, Drama, Suspense':'Action','Drama, Fantasy':'Drama', 'Fantasy, Kids':'Kids',
       'Documentary, Special Interest':'Documentary',
       'Action, Science Fiction, Suspense':'Action','Adventure, Kids':'Kids',
       'Horror, Suspense':'Horror', 'Documentary, Sports':'Documentary',
       'Horror, Science Fiction':'Horror', 'Kids, Special Interest':'Kids',
       'Comedy, Talk Show and Variety':'Comedy',
       'Action, Anime, Comedy':'Anime',
       'Arts, Entertainment, and Culture, Comedy, Drama':'Comedy',
       'Animation, Anime, Fantasy':'Anime', 'Action, Adventure, Animation':'Action',
       'Anime, Kids':'Kids','Drama, Suspense':'Drama',
       'Fitness, Special Interest':'Fitness',
       'Faith and Spirituality, Special Interest':'Faith and Spirituality',
       'Action, Military and War, Western':'Action',
       'Arts, Entertainment, and Culture, Comedy, Talk Show and Variety':'Comedy',
       'Documentary, Science Fiction':'Documentary',
       'Adventure, Animation, Kids':'Kids', 'Fantasy, Science Fiction, Suspense':'Science Fiction',
       'Documentary, LGBTQ':'Documentary',
       'Drama, Romance, Suspense':'Drama', 'Comedy, Special Interest, Unscripted':'Comedy',
       'Documentary, Military and War':'Documentary', 'Animation, Kids':'Kids',
       'Action, Drama':'Action', 'Comedy, Documentary, Unscripted':'Comedy',
       'Action, Drama, Sports':'Action',
       'Arts, Entertainment, and Culture, Comedy':'Comedy',
       'Arts, Entertainment, and Culture, Comedy, Special Interest':'Comedy',
       'Documentary, International, Special Interest':'Documentary',
       'Comedy, Science Fiction':'Comedy', 'Drama, Western':'Drama',
       'Arts, Entertainment, and Culture':'Arts', 'Drama, Special Interest':'Drama',
       'Action, Science Fiction':'Science Fiction',
       'Documentary, Faith and Spirituality, Special Interest':'Documentary',
       'Action, Drama, Special Interest':'Action', 'Drama, Young Adult Audience':'Drama',
       'Drama, Military and War':'Drama', 'Arthouse, Drama':'Drama',
       'Documentary, Kids, Special Interest':'Documentary', 'Action, Adventure, Comedy':'Action',
       'Military and War, Western':'Western', 'Action, Comedy, Drama':'Comedy',
       'Comedy, International':'Comedy', 'Drama, Romance':'Drama',
       'Drama, Horror, Suspense':'Drama', 'Animation, Comedy, Kids':'Kids',
       'Action, Suspense':'Action',
       'Arts, Entertainment, and Culture, Documentary':'Documentary',
       'Documentary, Drama, Unscripted':'Documentary', 'Action, Drama, International':'Drama',
       'Drama, Science Fiction, Suspense':'Science Fiction', 'International, Suspense':'International',
       'Drama, International, Suspense':'Drama', 'Action, International':'Action',
       'Anime, Drama, International':'Anime', 'Action, Documentary, Sports':'Documentary',
       'Comedy, Horror':'Comedy', 'Action, Adventure, Anime':'Anime', 'Animation, Drama':'Drama',
       'Special Interest, Sports':'Sports', 'Action, Comedy':'Comedy',
       'Arthouse, Comedy, Drama':'Comedy',
       'Arts, Entertainment, and Culture, Documentary, Special Interest':'Documentary',
       'Animation, International, Kids':'Kids', 'Comedy, Drama, LGBTQ':'Comedy',
       'Action, Adventure':'Action', 'Comedy, Drama, Sports':'Comedy', 'Comedy, Romance':'Comedy',
       'Documentary, Drama, Sports':'Documentary', 'Drama, International, Romance':'Drama',
       'Comedy, Drama, Romance':'Comedy', 'Animation, Anime, Drama':'Anime',
       'Action, Drama, Kids':'Kids', 'Fantasy, Horror, International':'Horror',
       'Action, Animation, Kids':'Kids',
       'Drama, Faith and Spirituality, Special Interest':'Drama',
       'Action, Drama, Western':'Action', 'Action, Adventure, Suspense':'Action',
       'Documentary, International':'Documentary', 'Adventure, Fantasy':'Adventure',
       'Action, Romance, Western':'Western', 'Documentary, Talk Show and Variety':'Documentary',
       'Documentary, Drama, LGBTQ':'Documentary', 'Documentary, Sports, Unscripted':'Documentary',
       'Comedy, Kids':'Kids', 'Arts, Entertainment, and Culture, Drama':'Drama',
       'Music Videos and Concerts, Special Interest':'Special Interest',
       'Drama, Faith and Spirituality, Romance':'Drama',
       'Drama, Faith and Spirituality, LGBTQ':'Drama',
       'Drama, Suspense, Young Adult Audience':'Drama',
       'Drama, LGBTQ, Unscripted':'Drama',
       'Documentary, Music Videos and Concerts':'Documentary',
       'Drama, Faith and Spirituality':'Drama', 'Special Interest, Unscripted':'Special Interest',
       'Action, Fantasy':'Action', 'Action, Drama, Horror':'Action',
       'International, Music Videos and Concerts, Unscripted':'Unscripted',
       'Action, Kids':'Kids', 'Action, Drama, Romance':'Action', 'Drama, Sports':'Drama',
       'Documentary, Drama, Special Interest':'Documentary',
       'Animation, Comedy, Science Fiction':'Science Fiction', 'Adventure, Drama':'Adventure',
       'Comedy, Western':'Western', 'Animation, Kids, Special Interest':'Kids',
       'Drama, Unscripted, Young Adult Audience':'Drama', 'Drama, Kids':'Kids',
       'Documentary, Horror':'Documentary', 'Action, Comedy, Horror':'Action',
       'Comedy, Suspense':'Comedy', 'Animation, Drama, Faith and Spirituality':'Drama',
       'Drama, Historical':'Drama', 'Drama, Science Fiction':'Science Fiction',
       'Comedy, Documentary, Special Interest':'Documentary',
       'Action, Drama, Historical':'Action', 'Animation, Anime, Kids':'Kids',
       'Romance, Science Fiction':'Science Fiction', 'Drama, Historical, Military and War':'Drama',
       'Drama, Faith and Spirituality, Suspense':'Drama',
       'Arthouse, Arts, Entertainment, and Culture, Drama':'Drama',
       'Documentary, Special Interest, Unscripted':'Documentary',
       'Comedy, Young Adult Audience':'Comedy', 'Action, Special Interest':'Action',
       'Action, Documentary, Unscripted':'Action',
       'Documentary, Special Interest, Sports':'Documentary',
       'Kids, Special Interest, Unscripted':'Kids',
       'Comedy, Documentary, Sports':'Documentary',
       'Arts, Entertainment, and Culture, Documentary, Music Videos and Concerts':'Documentary',
       'Horror, Unscripted':'Horror', 'Documentary, Drama':'Documentary', 'Suspense, Western':'Western',
       'Arts, Entertainment, and Culture, Comedy, Romance':'Comedy',
       'Arthouse, Arts, Entertainment, and Culture, Comedy':'Comedy',
       'Drama, Historical, International':'Drama',
       'Action, Kids, Science Fiction':'Kids', 'Action, Military and War':'Action',                   
       'Action, Horror':'Action',
       'Horror, Young Adult Audience':'Horror', 'Action, Adventure, Drama':'Action',
       'Arts, Entertainment, and Culture, Drama, Romance':'Drama',
       'Action, Horror, Suspense':'Action', 'Comedy, Drama, Kids':'Kids',
       'Action, Fantasy, Science Fiction':'Action',
       'Documentary, Faith and Spirituality':'Documentary',
       'Arthouse, Arts, Entertainment, and Culture, Documentary':'Documentary',
       'Drama, Special Interest, Unscripted':'Unscripted',
       'Adventure, Drama, Military and War':'Adventure', 'Documentary, Unscripted':'Documentary',
       'Adventure, Documentary, Military and War':'Documentary', 'Documentary, Kids':'Kids',
       'Military and War, Special Interest':'Special Interest', 'Arthouse, Drama, Suspense':'Drama',
       'Comedy, Drama, International':'Comedy',
       'Comedy, International, Young Adult Audience':'Comedy',
       'Action, Anime, Fantasy':'Anime',
       'Documentary, Special Interest, Suspense':'Documentary',
       'Action, Adventure, Documentary':'Documentary',
       'Animation, Faith and Spirituality, Kids':'Kids',
       'Animation, Documentary, Kids':'Kids', 'Animation, Kids, Sports':'Kids',
       'Arthouse, Drama, Romance':'Drama', 'Action, Young Adult Audience':'Action',                   
       'Drama, Faith and Spirituality, Kids':'Drama',
       'Drama, Science Fiction, Special Interest':'Science Fiction',
       'Action, Adventure, Science Fiction':'Science Fiction', 'Adventure, Drama, Western':'Western',
       'Arts, Entertainment, and Culture, Comedy, Military and War':'Comedy',
       'Drama, Horror':'Horror',
       'Arts, Entertainment, and Culture, Drama, Western':'Western',
       'Comedy, Drama, Suspense':'Comedy', 'Animation, Comedy':'Comedy',
       'Kids, Science Fiction':'Kids', 'Adventure, Comedy, Kids':'Kids',
       'Comedy, Drama, Young Adult Audience':'Comedy', 'Drama, LGBTQ':'Drama',
       'Fantasy, Science Fiction':'Science Fiction', 'International, Unscripted':'Unscripted',
       'Arthouse, Comedy':'Comedy', 'Sports, Unscripted':'Unscripted',
       'Arts, Entertainment, and Culture, Comedy, Documentary':'Documentary',
       'Adventure, Drama, Suspense':'Adventure',
       'Action, Horror, Science Fiction':'Science Fiction', 'Drama, LGBTQ, Romance':'Drama',
       'Comedy, International, Unscripted':'Comedy', 'Drama, Kids, Romance':'Kids',
       'International, Special Interest':'Special Interest',
       'Action, Adventure, International':'Action',
       'Documentary, Military and War, Special Interest':'Documentary',
       'Adventure, Documentary, Special Interest':'Documentary',
       'Action, Military and War, Suspense':'Action', 'Anime, Drama':'Anime',
       'Horror, Science Fiction, Suspense':'Science Fiction',
       'Adventure, Drama, Faith and Spirituality':'Adventure',
       'Arts, Entertainment, and Culture, Drama, Kids':'Kids',
       'Comedy, Drama, Special Interest':'Comedy',
       'Action, Documentary, Special Interest':'Documentary',
       'Animation, Anime, Horror':'Anime', 'Arthouse, Special Interest':'Special Interest',
       'Action, International, Suspense':'Action', 'Action, Sports':'Action',
       'Animation, Anime':'Anime', 'Drama, Historical, Suspense':'Drama',
       'Talk Show and Variety':'Talk Show','Drama, Unscripted':'Unscripted',
       'Drama, Horror, Special Interest':'Drama', 'LGBTQ, Special Interest':'Special Interest',
       'Action, Romance':'Action', 'LGBTQ, Romance':'Romance', 'Horror, International':'Horror',
       'Drama, Fantasy, Suspense':'Drama', 'Comedy, Kids, Talk Show and Variety':'Kids',
       'Romance, Suspense':'Romance', 'Drama, Fantasy, Science Fiction':'Science Fiction',
       'Arts, Entertainment, and Culture, Comedy, International':'Comedy',
       'Action, Documentary':'Documentary', 'Action, Drama, Science Fiction':'Science Fiction',
       'Kids, Music Videos and Concerts':'Kids',
       'Documentary, Horror, Special Interest':'Documentary', 'Comedy, LGBTQ, Romance':'Romance',
       'Action, Comedy, Western':'Western', 'Comedy, International, Romance':'Comedy',
       'Documentary, Suspense':'Documentary', 'Action, Arthouse, Drama':'Drama',
       'Action, Documentary, Faith and Spirituality':'Documentary',
       'Drama, Kids, LGBTQ':'Kids', 'Documentary, LGBTQ, Special Interest':'Documentary',
       'Drama, Fantasy, Historical':'Drama',
       'Arts, Entertainment, and Culture, Music Videos and Concerts':'Arts',
       'Action, Suspense, Young Adult Audience':'Action',
       'Action, Anime, International':'Anime',
       'International, Science Fiction, Suspense':'Science Fiction',
       'Action, Arthouse, Arts, Entertainment, and Culture':'Action',
       'Comedy, LGBTQ':'Comedy', 'Comedy, International, Special Interest':'Comedy','LGBTQ':'Romance',
       'Adventure, Comedy, Drama':'Adventure', 'Fantasy, Kids, Suspense':'Kids',
       'Arthouse, Comedy, Romance':'Comedy', 'Comedy, Sports':'Comedy',
       'Action, Comedy, Fantasy':'Comedy', 'Action, Sports, Suspense':'Action',
       'Action, Animation, Anime':'Anime', 'Anime, Comedy, International':'Anime',
       'Action, Adventure, Kids':'Kids', 'Action, Comedy, Documentary':'Documentary',
       'Drama, Fantasy, Kids':'Kids',
       'Arts, Entertainment, and Culture, Comedy, Unscripted':'Unscripted',
       'Action, Animation':'Action', 'Drama, Horror, Science Fiction':'Science Fiction',
       'Drama, International, Sports':'Drama', 'International, Sports':'Sports',
       'Science Fiction, Suspense':'Science Fiction', 'Comedy, Unscripted':'Unscripted',
       'Action, Special Interest, Sports':'Special Interest', 'LGBTQ, Suspense':'Romance',
       'Arts, Entertainment, and Culture, Comedy, LGBTQ':'Romance',
       'Arthouse, Drama, International':'Drama', 'Action, Suspense, Unscripted':'Unscripted',
       'Action, Comedy, LGBTQ':'Action', 'Special Interest, Western':'Western',
       'Kids, Western':'Kids', 'Drama, LGBTQ, Suspense':'Drama',
       'Comedy, Special Interest':'Comedy', 'Action, Drama, Military and War':'Action',
       'International, Romance':'Romance', 'Adventure, Drama, Kids':'Kids',
       'Documentary, Drama, Horror':'Documentary',
       'Science Fiction, Suspense, Unscripted':'Science Fiction',
       'Arts, Entertainment, and Culture, Drama, Young Adult Audience':'Drama',
       'LGBTQ, Special Interest, Unscripted':'Unscripted', 'Comedy, Drama, Fantasy':'Comedy',
       'Fitness, Kids, Special Interest':'Kids',
       'Documentary, Music Videos and Concerts, Special Interest':'Documentary',
       'Comedy, Horror, Suspense':'Horror',
       'Horror, Suspense, Young Adult Audience':'Horror', 'Adventure, Comedy':'Comedy',
       'Arthouse, Documentary':'Documentary',                   
       'Arts, Entertainment, and Culture, Drama, International':'Drama',
       'Drama, Kids, Special Interest':'Drama', 'Action, Adventure, Western':'Western',
       'Documentary, LGBTQ, Music Videos and Concerts':'Documentary',
       'Action, Unscripted':'Action', 'Drama, Horror, Western':'Western',
       'Comedy, Drama, Science Fiction':'Science Fiction',
       'Documentary, Science Fiction, Special Interest':'Documentary',
       'Adventure, Kids, Science Fiction':'Kids',
       'Drama, LGBTQ, Young Adult Audience':'Drama',
       'Action, Arts, Entertainment, and Culture, Comedy':'Action',
       'Action, Adventure, Fantasy':'Action', 'Adventure, Sports':'Adventure',
       'Comedy, Fantasy, Kids':'Kids', 'Drama, Horror, Young Adult Audience':'Horror',
       'Documentary, Drama, Suspense':'Documentary', 'Historical, Horror, Western':'Horror',
       'Action, Arts, Entertainment, and Culture, Drama':'Action',
       'Comedy, Historical':'Comedy', 'Fitness, Kids':'Kids',
       'Action, Animation, Fantasy':'Action',
       'Arts, Entertainment, and Culture, International, Unscripted':'Unscripted',
       'Kids, Sports':'Kids',
       'Arts, Entertainment, and Culture, Comedy, Young Adult Audience':'Comedy',
       'Documentary, Drama, Kids':'Kids', 'Anime, International, Kids':'Anime',
       'Action, Comedy, Special Interest':'Comedy',
       'Action, Comedy, Military and War':'Comedy',
       'Fantasy, Horror, Science Fiction':'Science Fiction',
       'Comedy, Music Videos and Concerts':'Comedy',
       'Arts, Entertainment, and Culture, Romance':'Romance',
       'LGBTQ, Romance, Sports':'Romance',
       'Arts, Entertainment, and Culture, Documentary, LGBTQ':'Documentary',
       'Action, Comedy, International':'Action',
       'Adventure, International, Suspense':'Adventure', 'Action, Fantasy, Suspense':'Action',
       'Animation, Arts, Entertainment, and Culture, Comedy':'Comedy',
       'Action, Kids, Suspense':'Kids', 'Action, Comedy, Kids':'Kids',
       'Kids, LGBTQ, Romance':'Kids', 'Action, International, Science Fiction':'Science Fiction',
       'Adventure, Comedy, Fantasy':'Adventure',
       'Animation, Kids, Music Videos and Concerts':'Kids',
       'Arts, Entertainment, and Culture, Comedy, Science Fiction':'Science Fiction',
       'Adventure, Fantasy, Kids':'Kids',
       'Arts, Entertainment, and Culture, International':'Arts',
       'Action, Kids, Military and War':'Action',
       'Comedy, Horror, Young Adult Audience':'Comedy',
       'Arts, Entertainment, and Culture, Music Videos and Concerts, Special Interest':'Special Interest',
       'Action, Comedy, Science Fiction':'Science Fiction',
       'Arts, Entertainment, and Culture, Horror, Suspense':'Horror',
       'Comedy, Sports, Young Adult Audience':'Comedy',
       'Action, Drama, Faith and Spirituality':'Action',
       'Drama, Music Videos and Concerts':'Drama',
       'Comedy, Faith and Spirituality, Kids':'Kids', 'Fantasy, Suspense':'Fantasy',
       'Arts, Entertainment, and Culture, Fantasy, Kids':'Kids',
       'Comedy, International, LGBTQ':'Comedy',
       'Arts, Entertainment, and Culture, Fantasy, Horror':'Fantasy',
       'Drama, International, Kids':'Kids', 'Arthouse, Comedy, Documentary':'Documentary',
       'Faith and Spirituality, Special Interest, Western':'Western',
       'Adventure, Suspense':'Adventure', 'Action, Comedy, Suspense':'Action','Suspense':'Action',
       'Anime, Kids, Science Fiction':'Kids',
       'Action, Comedy, Young Adult Audience':'Action', 'Animation, Suspense':'Animation','Fantasy':'Science Fiction',
       'Drama, Romance, Western':'Western', 'Adventure, Western':'Western',
       'Horror, International, Suspense':'Horror', 'Adventure, Drama, Romance':'Adventure',
       'Animation, Music Videos and Concerts':'Animation',
       'Comedy, Drama, Faith and Spirituality':'Comedy', 'Comedy, Kids, LGBTQ':'Kids',
       'Arts, Entertainment, and Culture, LGBTQ, Romance':'Romance',
       'Special Interest, Suspense':'Special Interest', 'Horror, Romance, Science Fiction':'Science Fiction',
       'Arts, Entertainment, and Culture, Fantasy, Science Fiction':'Science Fiction',
       'Drama, Military and War, Suspense':'Drama', 'Fantasy, Horror':'Horror',
       'Animation, Science Fiction':'Science Fiction', 'Animation, Drama, Science Fiction':'Science Fiction',
       'Faith and Spirituality, Music Videos and Concerts':'Faith and Spirituality',
       'Documentary, Faith and Spirituality, Music Videos and Concerts':'Documentary',
       'Arthouse, Drama, LGBTQ':'Drama', 'Comedy, Military and War, Suspense':'Comedy',
       'Faith and Spirituality, Kids, Special Interest':'Kids',
       'Kids, Young Adult Audience':'Kids', 'Animation, Drama, Kids':'Kids',
       'Animation, Comedy, Drama':'Drama', 'Comedy, Kids, Science Fiction':'Kids',
       'Action, Adventure, Faith and Spirituality':'Adventure',
       'Drama, Suspense, Western':'Western', 'Arthouse, LGBTQ, Romance':'Romance',
       'Action, Adventure, Sports':'Action', 'Comedy, Drama, Military and War':'Drama',
       'Action, Anime':'Anime', 'Comedy, Documentary':'Documentary',
       'Drama, International, Special Interest':'Special Interest',
       'Drama, Special Interest, Suspense':'Special Interest',
       'Action, Arts, Entertainment, and Culture, Music Videos and Concerts':'Action',
       'Drama, Romance, Special Interest':'Romance', 'Action, Documentary, Drama':'Documentary',
       'Arts, Entertainment, and Culture, Kids':'Kids',
       'Arts, Entertainment, and Culture, Drama, Science Fiction':'Science Fiction',
       'Arthouse, LGBTQ, Suspense':'Suspense', 'Drama, Horror, Romance':'Horror',
       'Arts, Entertainment, and Culture, Drama, Music Videos and Concerts':'Drama',
       'Action, Arthouse, Romance':'Romance',
       'Arts, Entertainment, and Culture, Kids, Science Fiction':'Kids',
       'Arthouse, Documentary, Special Interest':'Documentary',
       'Drama, Horror, International':'Drama',
       'Horror, International, Science Fiction':'Horror',
       'Animation, Young Adult Audience':'Animation', 'Action, Anime, Kids':'Kids',
       'Drama, Romance, Science Fiction':'Science Fiction', 'Animation, Romance':'Animation',
       'Action, Romance, Suspense':'Romance',
       'Arts, Entertainment, and Culture, Comedy, Suspense':'Comedy',
       'Action, Adventure, Horror':'Horror', 'Action, Adventure, Special Interest':'Adventure',
       'Comedy, Fantasy, Young Adult Audience':'Comedy', 'Arthouse, Comedy, LGBTQ':'Comedy',
       'Arthouse, Comedy, Special Interest':'Comedy',
       'Animation, Kids, Science Fiction':'Kids', 'Comedy, Horror, Romance':'Horror',
       'Animation, Kids, Young Adult Audience':'Kids',
       'Comedy, Romance, Young Adult Audience':'Romance',
       'International, LGBTQ, Suspense':'Suspense',
       'Arts, Entertainment, and Culture, LGBTQ':'Entertainment',
       'Drama, Special Interest, Sports':'Drama',
       'Arts, Entertainment, and Culture, Documentary, International':'Documentary',
       'Action, Romance, Science Fiction':'Science Fiction',
       'Comedy, Drama, Music Videos and Concerts':'Drama',
       'Comedy, Drama, Western':'Western', 'Arthouse, Young Adult Audience':'Young Adult Audience',
       'Action, International, Romance':'Action',
       'Arthouse, Horror, Science Fiction':'Science Fiction',
       'Action, Arts, Entertainment, and Culture':'Action',
       'Arthouse, Comedy, Horror':'Horror', 'Documentary, Kids, Science Fiction':'Kids',
       'Drama, Historical, Romance':'Drama', 'Action, Kids, Young Adult Audience':'Kids',
       'Animation, Horror':'Horror',
       'Arts, Entertainment, and Culture, Special Interest, Unscripted':'Unscripted',
       'Horror, Romance, Western':'Western',
       'Arts, Entertainment, and Culture, Comedy, Horror':'Comedy',
       'Arts, Entertainment, and Culture, Young Adult Audience':'Young Adult Audience',
       'Arthouse, Drama, Horror':'Horror', 'Comedy, Drama, Horror':'Horror',
       'Romance, Science Fiction, Western':'Western', 'Horror, Romance':'Romance',
       'Arthouse, Horror':'Horror', 'Animation, Kids, Suspense':'Kids',
       'Horror, Romance, Suspense':'Suspense',
       'Arts, Entertainment, and Culture, Drama, Suspense':'Suspense',
       'Kids, Special Interest, Sports':'Kids', 'Action, Animation, Drama':'Animation,',
       'Documentary, Horror, Suspense':'Documentary',
       'Action, Animation, Science Fiction':'Science Fiction',
       'Comedy, Romance, Special Interest':'Romance',
       'Arthouse, Drama, Science Fiction':'Science Fiction', 'Arthouse, Horror, Suspense':'Suspense',
       'Arts, Entertainment, and Culture, Drama, LGBTQ':'Drama',
       'Animation, Special Interest':'Animation', 'Romance, Suspense, Western':'Western',
       'Documentary, Drama, Faith and Spirituality':'Documentary',
       'Drama, International, Western':'Western',
       'Arthouse, Comedy, Science Fiction':'Science Fiction',
       'Comedy, Horror, Science Fiction':'Science Fiction', 'Action, Comedy, Romance':'Action',
       'Arts, Entertainment, and Culture, Comedy, Kids':'Kids',
       'Arts, Entertainment, and Culture, Comedy, Faith and Spirituality':'Comedy',
       'Action, Special Interest, Suspense':'Suspense',
       'Romance, Science Fiction, Suspense':'Science Fiction',
       'Documentary, Suspense, Unscripted':'Documentary',
       'Arthouse, Arts, Entertainment, and Culture':'Arthouse',
       'Drama, Fantasy, Sports':'Drama',
       'Arts, Entertainment, and Culture, Drama, Horror':'Drama',
       'Horror, Western':'Western', 'Romance, Western':'Western',
       'Adventure, Science Fiction, Suspense':'Science Fiction',
       'Arthouse, Comedy, International':'Comedy', 'Adventure, Drama, Fantasy':'Adventure',
       'Faith and Spirituality, Kids, Western':'Kids',
       'Adventure, Arthouse, Horror':'Horror', 'Comedy, Fantasy':'Comedy',
       'Arthouse, Horror, Romance':'Horror',
       'Arthouse, Arts, Entertainment, and Culture, Horror':'Horror',
       'Action, Arts, Entertainment, and Culture, Suspense':'Action',
       'Animation, Anime, Romance':'Anime',
       'Arthouse, Drama, Kids':'Kids', 'Action, Anime, Drama':'Anime',
       'Adventure, Comedy, Unscripted':'Unscripted',
       'Arthouse, Documentary, Music Videos and Concerts':'Documentary',
       'Action, Drama, Fantasy':'Action', 'Action, Arthouse, Horror':'Action',
       'Comedy, Horror, Kids':'Kids', 'Drama, Kids, Western':'Kids',
       'Comedy, Documentary, Drama':'Documentary', 'Anime, Drama, Sports':'Anime',
       'Arthouse, Romance':'Romance', 'Arthouse, Horror, International':'Horror',
       'Drama, Kids, Suspense':'Kids',
       'Special Interest, Talk Show and Variety, Unscripted':'Unscripted',
       'Anime, Comedy, Drama':'Anime'})

# %%
#Checking no mappings have been missed and then stream lining
am2['listed_in'].unique()
# Out:
# array(['Comedy', 'Drama', 'Action', 'Documentary', 'Kids', 'Horror',
#        'Science Fiction', 'Anime', 'TV Shows',
#        'Music Videos and Concerts', 'Fitness', 'Faith and Spirituality',
#        'Special Interest', 'Action, Western', 'Unscripted', 'Western',
#        'Arts', 'Sports', 'International', 'Adventure',
#        'Young Adult Audience', 'Animation', 'Talk Show', 'Romance',
#        'Historical', 'Fantasy', 'Suspense', 'Entertainment', 'Arthouse',
#        'Animation,', 'Military and War'], dtype=object)

# %%
am2 = am2.replace({'TV Shows':'Generic','Action, Western':'Western','International':'Generic','Fitness':'Sports','Arthouse':'Arts','Animation,':'Animation','Entertainment':'Generic','Military and War':'Historical'})
am2['listed_in'].unique()
# Out:
# array(['Comedy', 'Drama', 'Action', 'Documentary', 'Kids', 'Horror',
#        'Science Fiction', 'Anime', 'Generic', 'Music Videos and Concerts',
#        'Sports', 'Faith and Spirituality', 'Special Interest', 'Western',
#        'Unscripted', 'Arts', 'Adventure', 'Young Adult Audience',
#        'Animation', 'Talk Show', 'Romance', 'Historical', 'Fantasy',
#        'Suspense'], dtype=object)

# %%
am2.to_csv('amazon_edited.csv', index=False)

# %% [markdown]
# Splitting data set into TV Shows and Movies

# %%
#Removes all instances of content of type 'movie'
am3 = am2[am2["type"].str.contains("Movie") == False]
am3.to_csv('amazon_tv_shows.csv',index=False)
#Removes all instances of content of type 'TV Show'
am4 = am2[am2["type"].str.contains("TV Show") == False]
am4.to_csv('amazon_movies.csv',index=False)

# %% [markdown]
# Seperating TV show data set into individual CSV's for each genre

# %%
am3['listed_in'].unique()
# Out:
# array(['Kids', 'Comedy', 'Anime', 'Generic', 'Action', 'Drama', 'Sports',
#        'Western', 'Documentary', 'Unscripted', 'Horror', 'Arts',
#        'Special Interest', 'Science Fiction', 'Young Adult Audience',
#        'Animation', 'Talk Show', 'Adventure', 'Romance',
#        'Music Videos and Concerts'], dtype=object)

# %%
#csv for 'Kids'
amtv1 = am3[am3["listed_in"].str.contains('Comedy|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv1.to_csv('amazon_kids_tv.csv', index=False)
#csv for 'Comedy'
amtv2 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv2.to_csv('amazon_comedy_tv.csv', index=False)
#csv for 'Anime'
amtv3 = am3[am3["listed_in"].str.contains('Kids|Comedy|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv3.to_csv('amazon_anime_tv.csv', index=False)
#csv for 'Generic'
amtv4 = am3[am3["listed_in"].str.contains('Kids|Anime|Comedy|Action|Drama|Sports|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv4.to_csv('amazon_generic_tv.csv', index=False)
#csv for 'Action'
amtv5 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Comedy|Drama|Sports|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv5.to_csv('amazon_action_tv.csv', index=False)
#csv for 'Drama'
amtv6 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Comedy|Sports|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv6.to_csv('amazon_drama_tv.csv', index=False)
#csv for 'Sports'
amtv7 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Comedy|Western|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv7.to_csv('amazon_sports_tv.csv', index=False)
#csv for 'western'
amtv8 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Comedy|Documentary|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv8.to_csv('amazon_western_tv.csv', index=False)
#csv for 'Documentary'
amtv9 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Comedy|Unscripted|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv9.to_csv('amazon_documentary_tv.csv', index=False)
#csv for 'Unscripted'
amtv10 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Comedy|Horror|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv10.to_csv('amazon_unscripted_tv.csv', index=False)
#csv for 'Horror'
amtv11 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv11.to_csv('amazon_horror_tv.csv', index=False)
#csv for 'Arts'
amtv12 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Horror|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv12.to_csv('amazon_arts_tv.csv', index=False)
#csv for 'Special Interest'
amtv13 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv13.to_csv('amazon_special_tv.csv', index=False)
#csv for 'Science Fiction'
amtv14 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Young Adult Audience|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv14.to_csv('amazon_scifi_tv.csv', index=False)
#csv for 'Young adult audience'
amtv15 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Science Fiction|Animation|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv15.to_csv('amazon_ya_tv.csv', index=False)
#csv for 'Animation'
amtv16 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Science Fiction|Young Adult Audience|Talk Show|Adventure|Romance|Music Videos and Concerts') == False]
amtv16.to_csv('amazon_animated_tv.csv', index=False)
#csv for 'talk shows'
amtv17 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Science Fiction|Young Adult Audience|Animation|Adventure|Romance|Music Videos and Concerts') == False]
amtv17.to_csv('amazon_talk_show_tv.csv', index=False)
#csv for Adventure
amtv18 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Romance|Music Videos and Concerts') == False]
amtv18.to_csv('amazon_adventure_tv.csv', index=False)
#csv for Romance
amtv19 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Music Videos and Concerts') == False]
amtv19.to_csv('amazon_romance_tv.csv', index=False)
#csv for Music Videos and Concerts
amtv20 = am3[am3["listed_in"].str.contains('Kids|Anime|Generic|Action|Drama|Sports|Western|Documentary|Unscripted|Comedy|Arts|Horror|Special Interest|Science Fiction|Young Adult Audience|Animation|Talk Show|Adventure|Romance') == False]
amtv20.to_csv('amazon_music_tv.csv', index=False)

# %% [markdown]
# Seperating movie data set into individual CSV's for each genre

# %%
am4['listed_in'].unique()
# Out:
# array(['Comedy', 'Drama', 'Action', 'Documentary', 'Kids', 'Horror',
#        'Science Fiction', 'Music Videos and Concerts', 'Sports',
#        'Faith and Spirituality', 'Special Interest', 'Western', 'Arts',
#        'Anime', 'Generic', 'Adventure', 'Young Adult Audience', 'Romance',
#        'Animation', 'Historical', 'Fantasy', 'Unscripted', 'Suspense'],
#       dtype=object)

# %%
#csv for 'comedy'
ammov1 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov1.to_csv('amazon_comedy_movies.csv', index=False)
#csv for 'Drama'
ammov2 = am4[am4["listed_in"].str.contains('Comedy|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov2.to_csv('amazon_drama_movies.csv', index=False)
#csv for 'Action'
ammov3 = am4[am4["listed_in"].str.contains('Comedy|Drama|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov3.to_csv('amazon_action_movies.csv', index=False)
#csv for 'Documentary'
ammov4 = am4[am4["listed_in"].str.contains('Drama|Action|Comedy|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov4.to_csv('amazon_documentary_movies.csv', index=False)
#csv for 'Kids'
ammov5 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Comedy|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov5.to_csv('amazon_kids_movies.csv', index=False)
#csv for 'Horror'
ammov6 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Comedy|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov6.to_csv('amazon_horror_movies.csv', index=False)
#csv for 'Science Fiction'
ammov7 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Comedy|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov7.to_csv('amazon_scifi_movies.csv', index=False)
#csv for 'Music Videos and Concerts'
ammov8 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Comedy|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov8.to_csv('amazon_music_movies.csv', index=False)
#csv for 'Sports'
ammov9 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Comedy|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov9.to_csv('amazon_sports_movies.csv', index=False)
#csv for 'Faith and Spirituality'
ammov10 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Comedy|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov10.to_csv('amazon_faith_movies.csv', index=False)
#csv for 'Special Interest'
ammov11 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Comedy|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov11.to_csv('amazon_special_movies.csv', index=False)
#csv for 'Western'
ammov12 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Comedy|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov11.to_csv('amazon_western_movies.csv', index=False)
#csv for 'Arts'
ammov13 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Comedy|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov13.to_csv('amazon_arts_movies.csv', index=False)
#csv for 'Anime'
ammov14 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Comedy|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov14.to_csv('amazon_anime_movies.csv', index=False)
#csv for 'Generic'
ammov15 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Comedy|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov15.to_csv('amazon_generic_movies.csv', index=False)
#csv for 'Adventure'
ammov16 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Comedy|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov16.to_csv('amazon_adventure_movies.csv', index=False)
#csv for 'Young Adult Audience'
ammov17 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Comedy|Romance|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov17.to_csv('amazon_ya_movies.csv', index=False)
#csv for 'Romance',
ammov18 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Comedy|Animation|Historical|Fantasy|Unscripted|Suspense') == False]
ammov18.to_csv('amazon_romance_movies.csv', index=False)
#csv for 'Animation'
ammov19 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Comedy|Historical|Fantasy|Unscripted|Suspense') == False]
ammov19.to_csv('amazon_animated_movies.csv', index=False)
#csv for 'Historical'
ammov20 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Comedy|Fantasy|Unscripted|Suspense') == False]
ammov20.to_csv('amazon_historical_movies.csv', index=False)
#csv for 'Fantasy'
ammov21 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Comedy|Unscripted|Suspense') == False]
ammov21.to_csv('amazon_fantasy_movies.csv', index=False)
#csv for 'Unscripted'
ammov22 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Comedy|Suspense') == False]
ammov22.to_csv('amazon_unscripted_movies.csv', index=False)
#csv for 'Suspense'
ammov23 = am4[am4["listed_in"].str.contains('Drama|Action|Documentary|Kids|Horror|Science Fiction|Music Videos and Concerts|Sports|Faith and Spirituality|Special Interest|Western|Arts|Anime|Generic|Adventure|Young Adult Audience|Romance|Animation|Historical|Fantasy|Unscripted|Comedy') == False]
ammov23.to_csv('amazon_suspense_movies.csv', index=False)
